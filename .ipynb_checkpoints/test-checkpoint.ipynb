# %%
using Plots

# %%
plot(sin, 0:0.1:2π)

# %%
using DelimitedFiles
a = readdlm("forbes.txt", Float64, '\n')
# Out:
# 17×2 Array{Float64,2}:
#  194.5  20.79
#  194.3  20.79
#  197.9  22.4
#  198.4  22.67
#  199.4  23.15
#  199.9  23.35
#  200.9  23.89
#  201.1  23.99
#  201.4  24.02
#  201.3  24.01
#  203.6  25.14
#  204.6  26.57
#  209.5  28.49
#  208.6  27.76
#  210.7  29.04
#  211.9  29.88
#  212.2  30.06

# %%
length(a)
# Out:
# 34
